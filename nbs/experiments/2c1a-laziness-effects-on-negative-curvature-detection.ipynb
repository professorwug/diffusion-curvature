# %%
#|hide
## Standard libraries
import os
import math
import numpy as np
import time
from fastcore.all import *
from nbdev.showdoc import *

# Configure environment
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false' # Tells Jax not to hog all of the memory to this process.
import nest_asyncio
nest_asyncio.apply()

## Imports for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgba
import seaborn as sns
sns.set()

## Progress bar
from tqdm.auto import tqdm, trange

## project specifics
import diffusion_curvature
import pygsp
import jax
import jax.numpy as jnp
from diffusion_curvature.graphs import *
from diffusion_curvature.datasets import *
from diffusion_curvature.core import *
from diffusion_curvature.utils import *
from diffusion_curvature.comparison_space import *
from diffusion_curvature.sadspheres import *
from diffusion_curvature.kernels import *

# %load_ext autoreload
# %autoreload 2
    
jax.devices()
jax.default_device = jax.devices("cpu")

# %% [markdown]
# # 2c1a Laziness of Diffusion and Negative Curvature Detection
# > 'Self-loops bad?'

# %% [markdown]
# We noticed incidentally in a preceeding notebook which now escapes our collective recollection -- in short (he said, with a spurt of confidence) we noticed that using a *fixed* kernel is not enough to restore 'sinity' to diffusion curvature. That kernel must also have no self loops.
#
# This is unexpected. That in high dimensions the bandwidth of a kernel might vary in spaces of different curvature -- this is expected. That in high dimensions, the self-laziness of a single step of diffusion would determine whether it is comparable in saddles and spheres -- that is bizarre.
#
# Here we reproduce this effect and further probe into it.

# %% [markdown]
# *Hypothesis*: When graphs have self loops, they are not as effectively compared in high dimensions, as when they don't.

# %%
import asyncio

import logging
logging.getLogger().setLevel(logging.ERROR)


def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)
    return wrapped

# %% [markdown]
# ## Dimension 2

# %% [markdown]
# Here we observe that everything is well separated, and that larger $k$ values separate better, with less noise, as expected.

# %%
import asyncio
from tqdm import trange
dim = 2
SS = SadSpheres(
    dimension = dim, # Dimension of saddles and spheres
    num_pointclouds = 100, # num pointclouds to make in total
    num_points = 2000, # num points per pointclouds
    noise_level = 0, # from 0 to 1. 1 is all noise.
    include_planes = True,
)

def adaptive_graph_former(X, alpha, k):
    W = gaussian_kernel(
        X, 
        kernel_type = "adaptive",
        k = k,
        anisotropic_density_normalization = alpha,
    )
    # set diagonal of W to zero
    np.fill_diagonal(W, 0)
    G = pygsp.graphs.Graph(W)
    return G
    

async def process_alpha_k(X, alpha, k):
    global SS
    graph_former = partial(adaptive_graph_former, k = k, alpha = alpha)
    G = graph_former(X)
    DC = DiffusionCurvature(
        laziness_method="Wasserstein",
        flattening_method="Fixed",
        comparison_method="Subtraction",
        graph_former=graph_former,
        points_per_cluster=None,  # construct separate comparison spaces around each point
        comparison_space_size_factor=1,
    )
    ks = DC.curvature(G, dim=dim, t=25)
    SS.update(ks[0], method_name=f"DC with {k=} {alpha=}")

async def process_X(X, pbar):
    global SS
    tasks = []
    for alpha in [1]:
        for k in [5, 10, 25]:
            tasks.append(asyncio.create_task(process_alpha_k(X, alpha, k)))
    await asyncio.gather(*tasks)
    pbar.update(1)

async def main():
    global SS
    pbar = trange(len(SS), desc="Processing X's")
    for i, X in enumerate(SS):
        await process_X(X, pbar)
    pbar.close()

# Run the main function using asyncio.run()
asyncio.run(main())
# Out:
# Processing X's: 100%|██████████| 99/99 [04:27<00:00,  2.71s/it]

# %%
SS.plot()
SS.table()
# Out:
#                                                          pearson_r  sign_score
# ks                                                      (1.0, 0.0)    1.098612
# DC with k=5 alpha=1    (0.8377663883518671, 3.107262234835446e-27)    0.464663
# DC with k=10 alpha=1    (0.8298572574242141, 2.55950536163737e-26)    0.467153
# DC with k=25 alpha=1  (0.7283408003942018, 1.3077001090634165e-17)    0.464663

# %% [markdown]
# ## Dimension 3

# %%
import asyncio
from tqdm import trange
dim = 3
SS = SadSpheres(
    dimension = dim, # Dimension of saddles and spheres
    num_pointclouds = 100, # num pointclouds to make in total
    num_points = 2000, # num points per pointclouds
    noise_level = 0, # from 0 to 1. 1 is all noise.
    include_planes = True,
)

async def process_alpha_k(X, alpha, k, t):
    global SS
    graph_former = partial(get_adaptive_graph, alpha=alpha, k=k)
    G = graph_former(X)
    DC = DiffusionCurvature(
        laziness_method="Wasserstein",
        flattening_method="Fixed",
        comparison_method="Subtraction",
        graph_former=graph_former,
        points_per_cluster=None,  # construct separate comparison spaces around each point
        comparison_space_size_factor=1,
    )
    ks = DC.curvature(G, t=t, dim=dim)
    SS.update(ks[0], method_name=f"DC with {k=} {alpha=} {t=}")

async def process_X(X, pbar):
    global SS
    tasks = []
    for alpha in [1]:
        for k in [5]:
            for t in [25]:
                tasks.append(asyncio.create_task(process_alpha_k(X, alpha, k, t)))
    await asyncio.gather(*tasks)
    pbar.update(1)

async def main():
    global SS
    pbar = trange(len(SS), desc="Processing X's")
    for i, X in enumerate(SS):
        await process_X(X, pbar)
    pbar.close()

# Run the main function using asyncio.run()
asyncio.run(main())
# Out:
# Processing X's:   0%|                                                                                                               | 0/99 [00:00<?, ?it/s]2024-03-08 14:15:47,727:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:48,471:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   1%|█                                                                                                      | 1/99 [00:01<02:15,  1.38s/it]2024-03-08 14:15:49,121:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:49,742:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   2%|██                                                                                                     | 2/99 [00:02<02:08,  1.33s/it]2024-03-08 14:15:50,436:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:51,034:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   3%|███                                                                                                    | 3/99 [00:03<02:04,  1.30s/it]2024-03-08 14:15:51,670:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:52,611:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   4%|████▏                                                                                                  | 4/99 [00:05<02:12,  1.40s/it]2024-03-08 14:15:53,176:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:53,618:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   5%|█████▏                                                                                                 | 5/99 [00:06<01:57,  1.25s/it]2024-03-08 14:15:54,154:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:54,592:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   6%|██████▏                                                                                                | 6/99 [00:07<01:47,  1.16s/it]2024-03-08 14:15:55,138:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:55,572:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   7%|███████▎                                                                                               | 7/99 [00:08<01:41,  1.10s/it]2024-03-08 14:15:56,135:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:56,677:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   8%|████████▎                                                                                              | 8/99 [00:09<01:40,  1.11s/it]2024-03-08 14:15:57,254:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:57,795:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   9%|█████████▎                                                                                             | 9/99 [00:10<01:39,  1.11s/it]2024-03-08 14:15:58,382:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:15:58,933:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  10%|██████████▎                                                                                           | 10/99 [00:11<01:39,  1.12s/it]2024-03-08 14:15:59,561:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 14:16:00,177:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:
# --> 111     for name, member in inspect.getmembers(self, predicate=inspect.ismethod):
#     112         if hasattr(member, 'tag') and getattr(member, 'tag') == 'metric':
#     113             tagged_functions.append(member)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/inspect.py:595, in getmembers(object, predicate)
#     592 def getmembers(object, predicate=None):
#     593     """Return all members of an object as (name, value) pairs sorted by name.
#     594     Optionally, only return members that satisfy a given predicate."""
# --> 595     return _getmembers(object, predicate, getattr)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/inspect.py:573, in _getmembers(object, predicate, getter)
#     568 for key in names:
#     569     # First try to get the value via getattr.  Some descriptors don't
#     570     # like calling their __get__ (see bug #1785), so fall back to
#     571     # looking in the __dict__.
#     572     try:
# --> 573         value = getter(object, key)
#     574         # handle the duplicate key
#     575         if key in processed:
#
# TypeError: descriptor '__weakref__' for 'SadSpheres' objects doesn't apply to a 'SadSpheres' object

# %%
import asyncio
from tqdm import trange
dim = 3
SS = SadSpheres(
    dimension = dim, # Dimension of saddles and spheres
    num_pointclouds = 18, # num pointclouds to make in total
    num_points = 8000, # num points per pointclouds
    noise_level = 0, # from 0 to 1. 1 is all noise.
    include_planes = True,
)

async def process_alpha_k(X, alpha, k, t):
    global SS
    graph_former = partial(get_adaptive_graph, alpha=alpha, k=k)
    G = graph_former(X)
    DC = DiffusionCurvature(
        laziness_method="Wasserstein",
        flattening_method="Fixed",
        comparison_method="Subtraction",
        graph_former=graph_former,
        points_per_cluster=None,  # construct separate comparison spaces around each point
        comparison_space_size_factor=1,
    )
    ks = DC.curvature(G, t=t, dim=dim)
    SS.update(ks[0], method_name=f"DC with {k=} {alpha=} {t=}")

async def process_X(X, pbar):
    global SS
    tasks = []
    for alpha in [1]:
        for k in [5]:
            for t in [25]:
                tasks.append(asyncio.create_task(process_alpha_k(X, alpha, k, t)))
    await asyncio.gather(*tasks)
    pbar.update(1)

async def main():
    global SS
    pbar = trange(len(SS), desc="Processing X's")
    for i, X in enumerate(SS):
        await process_X(X, pbar)
    pbar.close()

# Run the main function using asyncio.run()
asyncio.run(main())
# Out:
# Processing X's:   0%|                                                                                                               | 0/18 [00:00<?, ?it/s]2024-03-08 15:21:59,409:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:22:12,573:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:   6%|█████▋                                                                                                 | 1/18 [00:27<07:39, 27.02s/it]2024-03-08 15:22:26,750:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:22:38,516:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  11%|███████████▍                                                                                           | 2/18 [00:52<07:00, 26.28s/it]2024-03-08 15:22:52,100:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:23:04,216:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  17%|█████████████████▏                                                                                     | 3/18 [01:18<06:31, 26.07s/it]2024-03-08 15:23:17,918:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:23:29,555:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  22%|██████████████████████▉                                                                                | 4/18 [01:44<06:02, 25.87s/it]2024-03-08 15:23:43,495:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:23:55,208:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  28%|████████████████████████████▌                                                                          | 5/18 [02:09<05:33, 25.67s/it]2024-03-08 15:24:08,706:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:24:20,782:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  33%|██████████████████████████████████▎                                                                    | 6/18 [02:35<05:07, 25.64s/it]2024-03-08 15:24:34,228:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:24:45,866:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  39%|████████████████████████████████████████                                                               | 7/18 [03:00<04:41, 25.59s/it]2024-03-08 15:24:59,884:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:25:11,525:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  44%|█████████████████████████████████████████████▊                                                         | 8/18 [03:25<04:14, 25.46s/it]2024-03-08 15:25:24,932:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:25:36,994:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  50%|███████████████████████████████████████████████████▌                                                   | 9/18 [03:51<03:49, 25.48s/it]2024-03-08 15:25:50,344:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:26:01,940:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  56%|████████████████████████████████████████████████████████▋                                             | 10/18 [04:16<03:23, 25.41s/it]2024-03-08 15:26:15,884:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:26:27,497:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  61%|██████████████████████████████████████████████████████████████▎                                       | 11/18 [04:41<02:57, 25.34s/it]2024-03-08 15:26:40,923:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:26:53,062:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  67%|████████████████████████████████████████████████████████████████████                                  | 12/18 [05:07<02:32, 25.43s/it]2024-03-08 15:27:06,542:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:27:18,265:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  72%|█████████████████████████████████████████████████████████████████████████▋                            | 13/18 [05:32<02:07, 25.46s/it]2024-03-08 15:27:32,183:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:27:43,761:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  78%|███████████████████████████████████████████████████████████████████████████████▎                      | 14/18 [05:57<01:41, 25.35s/it]2024-03-08 15:27:57,173:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:28:09,401:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  83%|█████████████████████████████████████████████████████████████████████████████████████                 | 15/18 [06:23<01:16, 25.48s/it]2024-03-08 15:28:22,959:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:28:34,713:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  89%|██████████████████████████████████████████████████████████████████████████████████████████▋           | 16/18 [06:49<00:51, 25.54s/it]2024-03-08 15:28:48,707:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:29:00,406:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's:  94%|████████████████████████████████████████████████████████████████████████████████████████████████▎     | 17/18 [07:14<00:25, 25.45s/it]2024-03-08 15:29:13,803:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-08 15:29:26,017:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# Processing X's: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [07:40<00:00, 25.57s/it]

# %%
SS.plot(title="In Dimension 3")
SS.table()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 SS.plot(title="In Dimension 3")
# ----> 2 SS.table()
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/sadspheres.py:106, in SadSpheres.table(self)
#     105 def table(self):
# --> 106     self.compute_metrics()
#     107     return self.metric_table
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/sadspheres.py:68, in SadSpheres.compute_metrics(self)
#      66 def compute_metrics(self):
#      67     self._aggregate_labels()
# ---> 68     metrics = self._get_metrics()
#      69     self.metric_table = {}
#      70     for metric in metrics:
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/sadspheres.py:111, in SadSpheres._get_metrics(self)
#     109 def _get_metrics(self):
#     110     tagged_functions = []
# --> 111     for name, member in inspect.getmembers(self, predicate=inspect.ismethod):
#     112         if hasattr(member, 'tag') and getattr(member, 'tag') == 'metric':
#     113             tagged_functions.append(member)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/inspect.py:595, in getmembers(object, predicate)
#     592 def getmembers(object, predicate=None):
#     593     """Return all members of an object as (name, value) pairs sorted by name.
#     594     Optionally, only return members that satisfy a given predicate."""
# --> 595     return _getmembers(object, predicate, getattr)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/inspect.py:573, in _getmembers(object, predicate, getter)
#     568 for key in names:
#     569     # First try to get the value via getattr.  Some descriptors don't
#     570     # like calling their __get__ (see bug #1785), so fall back to
#     571     # looking in the __dict__.
#     572     try:
# --> 573         value = getter(object, key)
#     574         # handle the duplicate key
#     575         if key in processed:
#
# TypeError: descriptor '__weakref__' for 'SadSpheres' objects doesn't apply to a 'SadSpheres' object

# %% [markdown]
# ## Dimension 4

# %%
import asyncio
from tqdm import trange
dim = 4
SS = SadSpheres(
    dimension = dim, # Dimension of saddles and spheres
    num_pointclouds = 100, # num pointclouds to make in total
    num_points = 2000, # num points per pointclouds
    noise_level = 0, # from 0 to 1. 1 is all noise.
    include_planes = True,
)

async def process_alpha_k(X, alpha, k):
    global SS
    graph_former = partial(get_adaptive_graph, alpha=alpha, k=k)
    G = graph_former(X)
    DC = DiffusionCurvature(
        laziness_method="Wasserstein",
        flattening_method="Fixed",
        comparison_method="Subtraction",
        graph_former=graph_former,
        points_per_cluster=None,  # construct separate comparison spaces around each point
        comparison_space_size_factor=1,
    )
    ks = DC.curvature(G, dim=dim, t=25)
    SS.update(ks[0], method_name=f"DC with {k=} {alpha=}")

async def process_X(X, pbar):
    global SS
    tasks = []
    for alpha in [0, 0.5, 1]:
        for k in [5, 10, 15, 25]:
            tasks.append(asyncio.create_task(process_alpha_k(X, alpha, k)))
    await asyncio.gather(*tasks)
    pbar.update(1)

async def main():
    global SS
    pbar = trange(len(SS), desc="Processing X's")
    for i, X in enumerate(SS):
        await process_X(X, pbar)
    pbar.close()

# Run the main function using asyncio.run()
asyncio.run(main())
# Out:
# Processing X's: 100%|█| 99/99 [14:39<00:00,  8.88s/

# %%
SS.plot()
SS.table()
# Out:
#                                                              pearson_r  \
# ks                                                          (1.0, 0.0)
# DC with k=5 alpha=0         (-0.04499011999076727, 0.6583554448582754)
# DC with k=10 alpha=0      (-0.28908536002322605, 0.003707113948176866)
# DC with k=15 alpha=0     (-0.30865419503597136, 0.0018814657194790557)
# DC with k=25 alpha=0    (-0.35141322780973505, 0.00036168370688376074)
# DC with k=5 alpha=0.5       (0.09450702089794012, 0.35212504851489146)
# DC with k=10 alpha=0.5     (-0.17165696995125101, 0.08933638174702259)
# DC with k=15 alpha=0.5     (-0.288984708115415, 0.0037196278447960834)
# DC with k=25 alpha=0.5   (-0.3461616122401221, 0.00044863764091177606)
# DC with k=5 alpha=1        (0.3372264655378036, 0.0006417995761138468)
# DC with k=10 alpha=1        (0.20616432150357922, 0.04062802514655108)
# DC with k=15 alpha=1         (0.11801380296109046, 0.2446752733599539)
# DC with k=25 alpha=1          (0.04736262959436114, 0.641552958013904)
#
#                         sign_score
# ks                        1.098612
# DC with k=5 alpha=0       0.261786
# DC with k=10 alpha=0      0.317535
# DC with k=15 alpha=0      0.211444
# DC with k=25 alpha=0      0.165383
# DC with k=5 alpha=0.5     0.261786
# DC with k=10 alpha=0.5    0.211444
# DC with k=15 alpha=0.5    0.227703
# DC with k=25 alpha=0.5    0.211444
# DC with k=5 alpha=1       0.298260
# DC with k=10 alpha=1      0.227703
# DC with k=15 alpha=1      0.261786
# DC with k=25 alpha=1      0.195659

# %% [markdown]
# # Fixed Kernel with Self Loops

# %% [markdown]
# ## Dimension 3

# %%
import asyncio
from tqdm import trange
dim = 3
SS = SadSpheres(
    dimension = dim, # Dimension of saddles and spheres
    num_pointclouds = 100, # num pointclouds to make in total
    num_points = 2000, # num points per pointclouds
    noise_level = 0, # from 0 to 1. 1 is all noise.
    include_planes = True,
)

def fixed_graph_former_self_loops(X, sigma, alpha):
    W = gaussian_kernel(
        X, 
        kernel_type = "fixed",
        sigma = sigma,
        anisotropic_density_normalization = alpha,
    )
    # set diagonal of W to zero
    # np.fill_diagonal(W, 0)
    G = pygsp.graphs.Graph(W)
    return G
    

async def process_alpha_k(X, alpha, sigma):
    global SS
    graph_former = partial(fixed_graph_former, sigma = sigma, alpha = alpha)
    G = graph_former(X)
    DC = DiffusionCurvature(
        laziness_method="Wasserstein",
        flattening_method="Fixed",
        comparison_method="Subtraction",
        graph_former=graph_former,
        points_per_cluster=None,  # construct separate comparison spaces around each point
        comparison_space_size_factor=1,
    )
    ks = DC.curvature(G, dim=dim, t=25)
    SS.update(ks[0], method_name=f"DC with {sigma=} {alpha=}")

async def process_X(X, pbar):
    global SS
    tasks = []
    for alpha in [1]:
        for sigma in [0.01, 0.05, 0.1, 0.2, 0.3, 0.5, 0.7]:
            tasks.append(asyncio.create_task(process_alpha_k(X, alpha, sigma)))
    await asyncio.gather(*tasks)
    pbar.update(1)

async def main():
    global SS
    pbar = trange(len(SS), desc="Processing X's")
    for i, X in enumerate(SS):
        await process_X(X, pbar)
    pbar.close()

# Run the main function using asyncio.run()
asyncio.run(main())
# Out:
# Processing X's:   0%|                                                                                                                                               | 0/99 [00:00<?, ?it/s]
# Processing X's:   1%|█▎                                                                                                                                     | 1/99 [00:06<09:56,  6.09s/it]
# Processing X's:   2%|██▋                                                                                                                                    | 2/99 [00:11<09:24,  5.82s/it]
# Processing X's:   3%|████                                                                                                                                   | 3/99 [00:17<09:19,  5.83s/it]
# Processing X's:   4%|█████▍                                                                                                                                 | 4/99 [00:23<09:16,  5.86s/it]
# Processing X's:   5%|██████▊                                                                                                                                | 5/99 [00:29<09:13,  5.88s/it]
# Processing X's:   6%|████████▏                                                                                                                              | 6/99 [00:35<09:03,  5.85s/it]
# Processing X's:   7%|█████████▌                                                                                                                             | 7/99 [00:41<09:03,  5.91s/it]
# Processing X's:   8%|██████████▉                                                                                                                            | 8/99 [00:47<08:55,  5.89s/it]
# Processing X's:   9%|████████████▎                                                                                                                          | 9/99 [00:52<08:38,  5.76s/it]
# Processing X's:  10%|█████████████▌                                                                                                                        | 10/99 [00:58<08:26,  5.69s/it]
# Processing X's:  11%|██████████████▉                                                                                                                       | 11/99 [01:03<08:20,  5.68s/it]
# Processing X's:  12%|████████████████▏                                                                                                                     | 12/99 [01:09<08:13,  5.67s/it]
# Processing X's:  13%|█████████████████▌                                                                                                                    | 13/99 [01:14<07:55,  5.53s/it]
# Processing X's:  14%|██████████████████▉                                                                                                                   | 14/99 [01:20<07:50,  5.53s/it]
# Processing X's:  15%|████████████████████▎                                                                                                                 | 15/99 [01:25<07:49,  5.59s/it]
|██████████████████████████████████████████████████████████████████████████████████████████████████▊                                   | 73/99 [06:37<02:34,  5.94s/it]
# Processing X's:  75%|████████████████████████████████████████████████████████████████████████████████████████████████████▏                                 | 74/99 [06:43<02:27,  5.90s/it]
# Processing X's:  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████▌                                | 75/99 [06:48<02:19,  5.79s/it]
# Processing X's:  77%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊                               | 76/99 [06:54<02:13,  5.80s/it]
# Processing X's:  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████▏                             | 77/99 [07:00<02:06,  5.77s/it]
# Processing X's:  79%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▌                            | 78/99 [07:06<01:59,  5.70s/it]
# Processing X's:  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▉                           | 79/99 [07:11<01:51,  5.59s/it]
# Processing X's:  81%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                         | 80/99 [07:16<01:44,  5.52s/it]
# Processing X's:  82%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                        | 81/99 [07:22<01:39,  5.51s/it]
# Processing X's:  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                       | 82/99 [07:27<01:31,  5.37s/it]
# Processing X's:  84%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                     | 83/99 [07:32<01:25,  5.31s/it]
# Processing X's:  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                    | 84/99 [07:37<01:19,  5.33s/it]
# Processing X's:  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████                   | 85/99 [07:43<01:14,  5.30s/it]
# Processing X's:  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 86/99 [07:48<01:08,  5.26s/it]
# Processing X's:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                | 87/99 [07:53<01:03,  5.30s/it]
# Processing X's:  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████               | 88/99 [07:59<00:58,  5.36s/it]
# Processing X's:  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍             | 89/99 [08:04<00:53,  5.31s/it]
# Processing X's:  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊            | 90/99 [08:09<00:47,  5.30s/it]
# Processing X's:  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏          | 91/99 [08:15<00:42,  5.36s/it]
# Processing X's:  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌         | 92/99 [08:20<00:37,  5.34s/it]
# Processing X's:  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉        | 93/99 [08:25<00:31,  5.27s/it]
# Processing X's:  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏      | 94/99 [08:30<00:26,  5.35s/it]
# Processing X's:  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌     | 95/99 [08:36<00:21,  5.39s/it]
# Processing X's:  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉    | 96/99 [08:41<00:15,  5.27s/it]
# Processing X's:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 97/99 [08:46<00:10,  5.27s/it]
# Processing X's:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 98/99 [08:52<00:05,  5.37s/it]
# Processing X's: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 99/99 [08:57<00:00,  5.43s/it]

# %%
SS.plot()
SS.table()
# Out:
#                                                                pearson_r  \
# ks                                                            (1.0, 0.0)
# DC with sigma=0.01 alpha=1    (0.033235004702199575, 0.7439896585895746)
# DC with sigma=0.05 alpha=1      (0.1059437287550668, 0.2966335787725885)
# DC with sigma=0.1 alpha=1   (0.7258912372690158, 1.8928710675263436e-17)
# DC with sigma=0.2 alpha=1   (0.995606670506727, 1.3754391058962552e-101)
# DC with sigma=0.3 alpha=1     (0.9366036884430339, 5.71277794980332e-46)
# DC with sigma=0.5 alpha=1    (0.957811034703306, 2.5048908781999233e-54)
# DC with sigma=0.7 alpha=1    (-0.2324110984821006, 0.020619153453011695)
#
#                             sign_score
# ks                            1.098612
# DC with sigma=0.01 alpha=1    0.014250
# DC with sigma=0.05 alpha=1    0.131744
# DC with sigma=0.1 alpha=1     0.298019
# DC with sigma=0.2 alpha=1     0.464663
# DC with sigma=0.3 alpha=1     0.462200
# DC with sigma=0.5 alpha=1     0.636514
# DC with sigma=0.7 alpha=1     0.096119

# %% [markdown]
# # Conclusion
