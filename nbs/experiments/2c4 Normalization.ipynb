# %%
#|hide
## Standard libraries
import os
import math
import numpy as np
import time
from fastcore.all import *
from nbdev.showdoc import *

# Configure environment
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false' # Tells Jax not to hog all of the memory to this process.
import nest_asyncio
nest_asyncio.apply()

## Imports for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgba
import seaborn as sns
sns.set()

## Progress bar
from tqdm.auto import tqdm, trange

## project specifics
import diffusion_curvature
import pygsp
import jax
import jax.numpy as jnp
from diffusion_curvature.graphs import *
from diffusion_curvature.datasets import *
from diffusion_curvature.core import *
from diffusion_curvature.utils import *
from diffusion_curvature.comparison_space import *
from diffusion_curvature.sadspheres import *

# %load_ext autoreload
# %autoreload 2
    
jax.devices()
jax.default_device = jax.devices("cpu")
# Out:
# [autoreload of diffusion_curvature.flattening.mioflow failed: Traceback (most recent call last):
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 2c4 Normalized Laziness
# > Controlling for diffusion speed

# %% [markdown]
# **Hypothesis**: Stuff will happen

# %% [markdown]
# # Test Case

# %%
X,ks = torus(2000,use_guide_points=True)

# %%
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G = graph_former(X)
G = pygsp.graphs.Graph(G.W)
DC = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Subtraction",
    diffusion_type = "heat kernel",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    smoothing=0,
)
# Out:
# 2024-03-07 17:23:19,423:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!

# %%
ks_dc, ks_0, P, Pt, t = DC.unsigned_curvature(G, t=200, _also_return_first_scale=True)

# %%
plot_3d(X,ks_dc,colorbar=True)

# %%
plot_3d(X,ks_0, colorbar=True)

# %%
from diffusion_curvature.heat_diffusion import jax_power_matrix

# %%
dz = jax_power_matrix(DC.P, 10) @ ks_0

# %%
dz
# Out:
# Array([1.0449486 , 1.2450544 , 0.9720626 , ..., 0.9172435 , 0.71132255,
#        0.90463585], dtype=float32)

# %%
jnp.sum(jax_power_matrix(DC.P, 10),axis=-1)
# Out:
# Array([0.9999877, 0.9992317, 0.9990181, ..., 1.0005169, 1.0004473,
#        1.0028   ], dtype=float32)

# %%
plot_3d(X,dz, colorbar=True)

# %%
DC.P[0]
# Out:
# Array([9.4516259e-01, 2.5215305e-25, 8.6485088e-30, ..., 2.1166708e-23,
#        2.5129790e-23, 3.8437673e-08], dtype=float32)

# %%
plot_3d(X, DC.P[0])

# %%
ks_dc
# Out:
# Array([5.1343727, 5.6625824, 5.718016 , ..., 5.111926 , 4.4068885,
#        4.9794197], dtype=float32)

# %%
ks_0
# Out:
# Array([10.147547, 21.268236,  8.729103, ..., 11.231356, 17.421688,
#        10.304707], dtype=float32)

# %%
divided = ks_dc - ks_0

# %%
plot_3d(X, divided)

# %% [markdown]
# # Higher Dimensional Data

# %%
from diffusion_curvature.sadspheres import *
import asyncio

import logging
logging.getLogger().setLevel(logging.ERROR)


def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)
    return wrapped

# %%
import asyncio
from tqdm import trange
dim = 3
SS = SadSpheres(
    dimension = dim, # Dimension of saddles and spheres
    num_pointclouds = 20, # num pointclouds to make in total
    num_points = 2000, # num points per pointclouds
    noise_level = 0, # from 0 to 1. 1 is all noise.
    include_planes = True,
)

async def process_alpha_k(X, alpha, k, t):
    global SS
    graph_former = partial(get_adaptive_graph, alpha=alpha, k=k)
    G = graph_former(X)
    G = pygsp.graphs.Graph(G.W)
    DC = DiffusionCurvature(
        laziness_method="Wasserstein",
        flattening_method="Fixed",
        comparison_method="Subtraction",
        diffusion_type="heat kernel",
        graph_former=graph_former,
        points_per_cluster=None,  # construct separate comparison spaces around each point
        comparison_space_size_factor=1,
    )
    ks = DC.unsigned_curvature(G, t=t)
    SS.update(ks[0], method_name=f"DC with {k=} {alpha=} {t=}")

async def process_X(X, pbar):
    global SS
    tasks = []
    for alpha in [1]:
        for k in [5]:
            for t in [1,100]:
                tasks.append(asyncio.create_task(process_alpha_k(X, alpha, k, t)))
    await asyncio.gather(*tasks)
    pbar.update(1)

async def main():
    global SS
    pbar = trange(len(SS), desc="Processing X's")
    for i, X in enumerate(SS):
        await process_X(X, pbar)
    pbar.close()

# Run the main function using asyncio.run()
asyncio.run(main())
# Out:
# [autoreload of diffusion_curvature.flattening.mioflow failed: Traceback (most recent call last):
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/piriac/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
# ]
#
# Processing X's:   0%|                                                                                                               | 0/18 [00:00<?, ?it/s]2024-03-07 17:35:20,851:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:20,959:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:22,926:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:23,026:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:   6%|█████▋                                                                                                 | 1/18 [00:06<01:45,  6.22s/it]2024-03-07 17:35:27,088:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:27,198:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:28,772:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:28,883:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  11%|███████████▍                                                                                           | 2/18 [00:11<01:34,  5.88s/it]2024-03-07 17:35:32,723:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:32,810:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:34,440:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:34,530:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  17%|█████████████████▏                                                                                     | 3/18 [00:17<01:24,  5.63s/it]2024-03-07 17:35:38,052:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:38,154:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:39,909:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:40,011:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  22%|██████████████████████▉                                                                                | 4/18 [00:23<01:22,  5.90s/it]2024-03-07 17:35:44,390:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:44,504:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:46,071:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:46,185:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  28%|████████████████████████████▌                                                                          | 5/18 [00:29<01:14,  5.76s/it]2024-03-07 17:35:49,885:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:49,974:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:51,591:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:51,681:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  33%|██████████████████████████████████▎                                                                    | 6/18 [00:34<01:08,  5.68s/it]2024-03-07 17:35:55,425:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:55,527:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:57,491:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:35:57,594:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  39%|████████████████████████████████████████                                                               | 7/18 [00:41<01:06,  6.05s/it]2024-03-07 17:36:02,223:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:02,336:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:04,059:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:04,175:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  44%|█████████████████████████████████████████████▊                                                         | 8/18 [00:47<01:01,  6.12s/it]2024-03-07 17:36:08,481:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:08,576:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:10,273:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:10,367:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  50%|███████████████████████████████████████████████████▌                                                   | 9/18 [00:53<00:54,  6.02s/it]2024-03-07 17:36:14,281:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:14,386:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:16,167:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:16,272:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  56%|████████████████████████████████████████████████████████▋                                             | 10/18 [00:59<00:49,  6.16s/it]2024-03-07 17:36:20,757:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:20,874:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:22,595:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:22,711:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  61%|██████████████████████████████████████████████████████████████▎                                       | 11/18 [01:05<00:42,  6.03s/it]2024-03-07 17:36:26,499:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:26,588:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:28,181:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:28,271:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  67%|████████████████████████████████████████████████████████████████████                                  | 12/18 [01:10<00:34,  5.75s/it]2024-03-07 17:36:31,604:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:31,708:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:33,370:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:33,475:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  72%|█████████████████████████████████████████████████████████████████████████▋                            | 13/18 [01:16<00:29,  5.88s/it]2024-03-07 17:36:37,794:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:37,907:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:39,497:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:39,838:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  78%|███████████████████████████████████████████████████████████████████████████████▎                      | 14/18 [01:23<00:23,  5.99s/it]2024-03-07 17:36:44,012:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:44,102:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:45,734:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:45,827:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  83%|█████████████████████████████████████████████████████████████████████████████████████                 | 15/18 [01:28<00:17,  5.84s/it]2024-03-07 17:36:49,512:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:49,614:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:51,411:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:51,513:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  89%|██████████████████████████████████████████████████████████████████████████████████████████▋           | 16/18 [01:34<00:11,  5.95s/it]2024-03-07 17:36:55,732:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:55,850:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:57,490:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:36:57,605:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's:  94%|████████████████████████████████████████████████████████████████████████████████████████████████▎     | 17/18 [01:40<00:05,  5.85s/it]2024-03-07 17:37:01,317:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:37:01,411:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:37:03,132:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:37:03,230:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
#
# Processing X's: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:46<00:00,  5.91s/it]

# %%
SS.plot(title="Unsigned Wasserstein Spread with Normalization by Division in dim 3")
SS.table()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 2
#       1 SS.plot(title="Unsigned Wasserstein Spread with Normalization by Division in dim 3")
# ----> 2 SS.table()
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/sadspheres.py:106, in SadSpheres.table(self)
#     105 def table(self):
# --> 106     self.compute_metrics()
#     107     return self.metric_table
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/sadspheres.py:68, in SadSpheres.compute_metrics(self)
#      66 def compute_metrics(self):
#      67     self._aggregate_labels()
# ---> 68     metrics = self._get_metrics()
#      69     self.metric_table = {}
#      70     for metric in metrics:
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/sadspheres.py:111, in SadSpheres._get_metrics(self)
#     109 def _get_metrics(self):
#     110     tagged_functions = []
# --> 111     for name, member in inspect.getmembers(self, predicate=inspect.ismethod):
#     112         if hasattr(member, 'tag') and getattr(member, 'tag') == 'metric':
#     113             tagged_functions.append(member)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/inspect.py:595, in getmembers(object, predicate)
#     592 def getmembers(object, predicate=None):
#     593     """Return all members of an object as (name, value) pairs sorted by name.
#     594     Optionally, only return members that satisfy a given predicate."""
# --> 595     return _getmembers(object, predicate, getattr)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/inspect.py:573, in _getmembers(object, predicate, getter)
#     568 for key in names:
#     569     # First try to get the value via getattr.  Some descriptors don't
#     570     # like calling their __get__ (see bug #1785), so fall back to
#     571     # looking in the __dict__.
#     572     try:
# --> 573         value = getter(object, key)
#     574         # handle the duplicate key
#     575         if key in processed:
#
# TypeError: descriptor '__weakref__' for 'SadSpheres' objects doesn't apply to a 'SadSpheres' object

# %%
import asyncio
from tqdm import trange
dim = 3
SS = SadSpheres(
    dimension = dim, # Dimension of saddles and spheres
    num_pointclouds = 20, # num pointclouds to make in total
    num_points = 2000, # num points per pointclouds
    noise_level = 0, # from 0 to 1. 1 is all noise.
    include_planes = True,
)

async def process_alpha_k(X, alpha, k, t):
    global SS
    graph_former = partial(get_adaptive_graph, alpha=alpha, k=k)
    G = graph_former(X)
    DC = DiffusionCurvature(
        laziness_method="Wasserstein",
        flattening_method="Fixed",
        comparison_method="Subtraction",
        graph_former=graph_former,
        points_per_cluster=None,  # construct separate comparison spaces around each point
        comparison_space_size_factor=1,
    )
    ks = DC.unsigned_curvature(G, t=t)
    SS.update(ks[0], method_name=f"DC with {k=} {alpha=} {t=}")

async def process_X(X, pbar):
    global SS
    tasks = []
    for alpha in [1]:
        for k in [5]:
            for t in [1,25]:
                tasks.append(asyncio.create_task(process_alpha_k(X, alpha, k, t)))
    await asyncio.gather(*tasks)
    pbar.update(1)

async def main():
    global SS
    pbar = trange(len(SS), desc="Processing X's")
    for i, X in enumerate(SS):
        await process_X(X, pbar)
    pbar.close()

# Run the main function using asyncio.run()
asyncio.run(main())
# Out:
# Processing X's: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:10<00:00,  1.67it/s]

# %%
SS.plot(title="Unsigned Wasserstein Spread with Normalization by Division in dim 3")
SS.table()
# Out:
#                                                             pearson_r  \
# ks                                                         (1.0, 0.0)
# DC with k=5 alpha=1 t=1    (0.39165551577749597, 0.10797919764552015)
# DC with k=5 alpha=1 t=100  (-0.33936876037069685, 0.1682795867329328)
#
#                            sign_score
# ks                           1.098612
# DC with k=5 alpha=1 t=1      0.000000
# DC with k=5 alpha=1 t=100    0.000000

# %% [markdown]
# # Conclusion
