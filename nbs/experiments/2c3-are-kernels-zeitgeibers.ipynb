# %%
#|hide
#|default_exp experiments.curvature_curves
## Standard libraries
import os
import math
import numpy as np
import time
from fastcore.all import *
from nbdev.showdoc import *
from functools import partial

# Configure environment
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false' # Tells Jax not to hog all of the memory to this process.

## Imports for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgba
import seaborn as sns
sns.set()

## Progress bar
from tqdm.auto import tqdm, trange

## project specifics
import diffusion_curvature
import pygsp
import jax
import jax.numpy as jnp
jax.devices()

from diffusion_curvature.graphs import *
from diffusion_curvature.datasets import *
from diffusion_curvature.core import *
from diffusion_curvature.utils import *
from diffusion_curvature.comparison_space import *

# Utility functions for literate programming
def get_var_name(instance):
    return [name for name, obj in globals().items() if obj is instance][0]

# %load_ext autoreload
# %autoreload 2
# Out:
# 2024-03-07 17:30:48.284316: W external/xla/xla/service/platform_util.cc:198] unable to create StreamExecutor for CUDA:0: failed initializing StreamExecutor for CUDA device ordinal 0: INTERNAL: failed call to cuDevicePrimaryCtxRetain: CUDA_ERROR_OUT_OF_MEMORY: out of memory; total memory reported: 25363087360

# %% [markdown]
# # 2c3 Are Kernels Zeitgeibers?
# > Perhaps comparison curvature is hampered by *time*, which goes faster or slower depending on kernel bandwidth?

# %% [markdown]
# The idea is that the disparities in our spatial comparisons are not due to the kernel disrupting the graph, but rather because the kernel assigns each graph a distinct timescale during diffusion. This is based on the idea that graph kernels act as "zeitgebers" of diffusion, with different curvatures leading to varying kernel parameters even when adaptive bandwidths are used. The issue is most pronounced in high-dimensional spaces, where sparse data makes the kernel more sensitive to curvature-induced variations between manifolds.

# %% [markdown]
# *Hypothesis*: The difference in 'curvature curves' between identically sampled manifolds operated on by different kernels can be equalized by changing the speed of diffusion time.

# %% [markdown]
# # Machinery

# %% [markdown]
# First we need an apparatus for conventiently computing 'curvature curves', that is the variations of laziness as a function of the power $t$. We'll piggyback on the existing `DiffusionCurvature` class with a mixins `@patch` that defines a 'curvature curve' function. This patch will create a linspace of `t`s, then call `self.unsigned_curvature(self.G, t)` over that linspace, returning the resutls.
#
# We'll then define a helper function, 'curvature_curves', that accepts as input any number of `DiffusionCurvature` classes with precomputed $P$s, and plots them the results of our patch.

# %%
import numpy as np
import matplotlib.pyplot as plt
from functools import partial
from fastcore.all import *
from diffusion_curvature.core import *

@patch
def curvature_curve(self:DiffusionCurvature, num_ts=50, idx = 0):
    t_values = np.arange(1, num_ts+1)
    curvatures = np.array([self.unsigned_curvature(self.G, int(t))[idx] for t in t_values])
    return t_values, curvatures

def show_curvature_curves(*diffusion_curvatures, num_ts = 50, idx = 0, scaling_fn = None, title = "Curvature Curves"):
    # fig, ax = plt.subplots(1)
    for dc in diffusion_curvatures:
        t_values, curvatures = dc.curvature_curve(num_ts = num_ts, idx=idx)
        plt.plot(t_values, curvatures, label=get_var_name(dc))
    plt.xlabel('Time ($t$)')
    plt.ylabel('Curvature')
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# We additionally have a `scaling_fn` which, given a pair of curvature curves, scales them.
# Here we define a couple of scaling functions:
#
# 1. *Bottom-up scaling*. Intuitively, the curvature curves should have the same behavior at small scales, where the graph is still (per the Manifold Hypothesis) locally Euclidean. This method aligns them to start at the same value, and then compresses time (equivalent to scaling the kernel bandwidth) such that the early values agree.

# %%
def bottom_up_scaling(curve1, curve2):
    # find curve with greater starting spread
    curves = [curve1, curve2]
    greater_idx = np.argmax([c[0] for c in curves])
    smaller_idx = 1-greater_idx
    # Discard values in the smaller idx below the starting point of greater idx
    only_greater_than_greater_than = [d >= curves[greater_idx][0] for d in curves[smaller_idx]]
    new_small_curve = curves[smaller_idx][only_greater_than_greater_than]
    new_curves = [new_small_curve, curves[greater_idx]]
    # Now that both kernels have an equal starting point, we scale time such that they have roughly equal first step
    # first_steps = [

# %% [markdown]
# # Results

# %% [markdown]
# ## Proof of Concept with the 2d Saddle, Plane, and Sphere

# %%
X_saddle, ks = rejection_sample_from_saddle(2000, intrinsic_dim=2)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_saddle = graph_former(X_saddle)
DC_saddle = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_saddle.fit_transform(G_saddle, dim=2, t=25)

# %%
X_sphere, ks_sphere = sphere(2000, d=2)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_sphere = graph_former(X_sphere)
DC_sphere = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_sphere.fit_transform(G_sphere, dim=2, t=25)

# %%
X_plane = plane(2000, dim=2)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_plane = graph_former(X_plane)
DC_plane = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_plane.fit_transform(G_plane, dim=2, t=25)

# %%
show_curvature_curves(DC_saddle, DC_plane, DC_sphere, num_ts=50, title = "Spread of Diffusion in 2 Manifolds")

# %% [markdown]
# ## How about the above in 3d?

# %%
X_saddle, ks = rejection_sample_from_saddle(2000, intrinsic_dim=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_saddle = graph_former(X_saddle)
DC_saddle = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_saddle.fit_transform(G_saddle, dim=2, t=25)

# %%
X_sphere, ks_sphere = sphere(2000, d=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_sphere = graph_former(X_sphere)
DC_sphere = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_sphere.fit_transform(G_sphere, dim=2, t=25)

# %%
X_plane = plane(2000, dim=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_plane = graph_former(X_plane)
DC_plane = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_plane.fit_transform(G_plane, dim=2, t=25)

# %%
show_curvature_curves(DC_saddle, DC_plane, DC_sphere, num_ts=50, title = " $W_1$ Spread of Diffusion in 3 Manifolds")

# %% [markdown]
# ## Performance with Kernel Matching Comparisons

# %%
X_saddle, ks = rejection_sample_from_saddle(2000, intrinsic_dim=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_saddle = graph_former(X_saddle)
DC_saddle = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Kernel Matching",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=True,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_saddle.fit_transform(G_saddle, dim=2, t=25)
# Out:
# Manifold spreads are [39.037666 35.224754 38.102276 ... 38.21082  37.89679  38.34002 ]
# average_dim_in_cluster=2
# {'params': {'kernel bandwidth': Array([nan], dtype=float32)}}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 14
#       3 G_saddle = graph_former(X_saddle)
#       4 DC_saddle = DiffusionCurvature(
#       5     laziness_method="Wasserstein",
#       6     flattening_method="Kernel Matching",
#    (...)
#      12     distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
#      13 )
# ---> 14 ks = DC_saddle.fit_transform(G_saddle, dim=2, t=25)
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:367, in DiffusionCurvature.fit_transform(self, G, t, idx, dim, knn, D, X)
#     357 def fit_transform(
#     358         self,
#     359         G:pygsp.graphs.Graph, # Input Graph
#    (...)
#     365         X = None, # if using a flattening method that requires a point cloud, supply it here.
#     366 ):
# --> 367     self.fit(G = G, t=t, idx=idx, dim=dim, knn=knn, D=D, X=X)
#     368     return self.ks
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:355, in DiffusionCurvature.fit(self, G, t, idx, dim, knn, D, X)
#     353 self.X = X
#     354 self.D = D
# --> 355 self.ks = self.curvature(G = G, t=t, idx=idx, dim=dim, knn=knn, D=D, X=X)
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:321, in DiffusionCurvature.curvature(self, G, t, idx, dim, knn, D, X)
#     319 if self.verbose: print(f"{average_dim_in_cluster=}")
#     320 average_spread_in_cluster = jnp.mean(manifold_spreads_nought[cluster_idxs])
# --> 321 fs = get_flat_spreads(
#     322     dimension = average_dim_in_cluster,
#     323     jump_of_diffusion = average_spread_in_cluster,
#     324     num_points_in_comparison = num_points_in_comparison,
#     325     cluster_idxs = cluster_idxs,
#     326     verbose=True
#     327     )
#     328 # fs = self.unsigned_curvature(G_euclidean,t,idx=0)
#     329 flat_spreads = flat_spreads.at[cluster_idxs].set(
#     330         fs
#     331     )
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:227, in DiffusionCurvature.curvature.<locals>.get_flat_spreads(dimension, jump_of_diffusion, num_points_in_comparison, cluster_idxs, verbose)
#     225     # W = fill_diagonal(euclidean_stuffs['A'],0)
#     226     G_euclidean = SimpleGraph(euclidean_stuffs['A'])
# --> 227     fs = self.unsigned_curvature(G_euclidean,t,idx=0)
#     228     return fs
#     229 case "Neural":
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:114, in DiffusionCurvature.unsigned_curvature(self, G, t, idx, _also_return_first_scale, D)
#     112 match self.diffusion_type:
#     113     case 'diffusion matrix':
# --> 114         P = normalize(G.W, norm="l1", axis=1)
#     115         if type(P) == scipy.sparse._csr.csr_matrix:
#     116             P = P.todense()
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:1817, in normalize(X, norm, axis, copy, return_norm)
#    1814 else:
#    1815     raise ValueError("'%d' is not a supported axis" % axis)
# -> 1817 X = check_array(
#    1818     X,
#    1819     accept_sparse=sparse_format,
#    1820     copy=copy,
#    1821     estimator="the normalize function",
#    1822     dtype=FLOAT_DTYPES,
#    1823 )
#    1824 if axis == 0:
#    1825     X = X.T
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/utils/validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
X_sphere, ks_sphere = sphere(2000, d=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_sphere = graph_former(X_sphere)
DC_sphere = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_sphere.fit_transform(G_sphere, dim=2, t=25)

# %%
X_plane = plane(2000, dim=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_plane = graph_former(X_plane)
DC_plane = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_plane.fit_transform(G_plane, dim=2, t=25)

# %%
show_curvature_curves(DC_saddle, DC_plane, DC_sphere, num_ts=50, title = " $W_1$ Spread of Diffusion in 3 Manifolds")

# %% [markdown]
# ## With the Heat Kernel

# %%
from diffusion_curvature.heat_diffusion import *

# %%
Ps = heat_diffusion_from_dirac(G_saddle, idx=0, t=[1,4, 15])

# %%
Ps[2]
# Out:
# Array([7.3713613e-01, 9.0329522e-09, 6.6748148e-06, ..., 3.1011127e-06,
#        8.0615180e-03, 8.9100868e-06], dtype=float32)

# %%
X_saddle, ks = rejection_sample_from_saddle(2000, intrinsic_dim=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_saddle = graph_former(X_saddle)
DC_saddle = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Subtraction",
    diffusion_type='heat kernel',
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_saddle.fit_transform(G_saddle, dim=2, t=25)
# Out:
# 2024-03-07 17:42:56,918:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-07 17:43:00,286:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 15
#       3 G_saddle = graph_former(X_saddle)
#       4 DC_saddle = DiffusionCurvature(
#       5     laziness_method="Wasserstein",
#       6     flattening_method="Fixed",
#    (...)
#      13     distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
#      14 )
# ---> 15 ks = DC_saddle.fit_transform(G_saddle, dim=2, t=25)
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:383, in DiffusionCurvature.fit_transform(self, G, t, idx, dim, knn, D, X)
#     373 def fit_transform(
#     374         self,
#     375         G:pygsp.graphs.Graph, # Input Graph
#    (...)
#     381         X = None, # if using a flattening method that requires a point cloud, supply it here.
#     382 ):
# --> 383     self.fit(G = G, t=t, idx=idx, dim=dim, knn=knn, D=D, X=X)
#     384     return self.ks
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:371, in DiffusionCurvature.fit(self, G, t, idx, dim, knn, D, X)
#     369 self.X = X
#     370 self.D = D
# --> 371 self.ks = self.curvature(G = G, t=t, idx=idx, dim=dim, knn=knn, D=D, X=X)
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:337, in DiffusionCurvature.curvature(self, G, t, idx, dim, knn, D, X)
#     335 if self.verbose: print(f"{average_dim_in_cluster=}")
#     336 average_spread_in_cluster = jnp.mean(manifold_spreads_nought[cluster_idxs])
# --> 337 fs = get_flat_spreads(
#     338     dimension = average_dim_in_cluster,
#     339     jump_of_diffusion = average_spread_in_cluster,
#     340     num_points_in_comparison = num_points_in_comparison,
#     341     cluster_idxs = cluster_idxs,
#     342     verbose=True
#     343     )
#     344 # fs = self.unsigned_curvature(G_euclidean,t,idx=0)
#     345 flat_spreads = flat_spreads.at[cluster_idxs].set(
#     346         fs
#     347     )
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:233, in DiffusionCurvature.curvature.<locals>.get_flat_spreads(dimension, jump_of_diffusion, num_points_in_comparison, cluster_idxs, verbose)
#     231     # scaling_factor = jnp.max(D[cluster_idxs][0])/jnp.max(D_euclidean[0])
#     232     D_euclidean = D_euclidean * scaling_factor
# --> 233 fs = self.unsigned_curvature(G_euclidean,t,idx=0) #,D=D_euclidean)
#     234 if self.verbose: print(f"comparison entropy is {fs}")
#     235 return fs
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:147, in DiffusionCurvature.unsigned_curvature(self, G, t, idx, _also_return_first_scale, D)
#     144 case "Wasserstein":
#     145     if D is None:
#     146         # raise NotImplementedError("If using Wasserstein-style diffusion curvature, you must pass in precomputed manifold distances with the 'D = ' parameter. If you don't want to compute those, we recommend setting the laziness type to 'Entropic'")
# --> 147         D = phate_distances(self.P_dist) #TODO: Could be more efficient here if there's an idx
#     148     laziness = wasserstein_spread_of_diffusion(D,self.Pt) if idx is None else wasserstein_spread_of_diffusion(D[idx],self.Pt[idx])
#     149     if _also_return_first_scale: laziness_nought = wasserstein_spread_of_diffusion(D,self.P)
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/distances.py:35, in phate_distances(Pt)
#      33 def phate_distances(Pt):
#      34     log_Pts = -jnp.log(Pt + 1e-6)
# ---> 35     D = pairwise_distances(log_Pts, log_Pts)
#      36     return D
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:1579, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1576 X, Y, dtype = _return_float_dtype(X, Y)
#    1578 if effective_n_jobs(n_jobs) == 1:
# -> 1579     return func(X, Y, **kwds)
#    1581 # enforce a threading backend to prevent data communication overhead
#    1582 fd = delayed(_dist_wrapper)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:300, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     224 def euclidean_distances(
#     225     X, Y=None, *, Y_norm_squared=None, squared=False, X_norm_squared=None
#     226 ):
#     227     """
#     228     Compute the distance matrix between each pair from a vector array X and Y.
#     229
#    (...)
#     298            [1.41421356]])
#     299     """
# --> 300     X, Y = check_pairwise_arrays(X, Y)
#     302     if X_norm_squared is not None:
#     303         X_norm_squared = check_array(X_norm_squared, ensure_2d=False)
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:146, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     143     dtype = dtype_float
#     145 if Y is X or Y is None:
# --> 146     X = Y = check_array(
#     147         X,
#     148         accept_sparse=accept_sparse,
#     149         dtype=dtype,
#     150         copy=copy,
#     151         force_all_finite=force_all_finite,
#     152         estimator=estimator,
#     153     )
#     154 else:
#     155     X = check_array(
#     156         X,
#     157         accept_sparse=accept_sparse,
#    (...)
#     161         estimator=estimator,
#     162     )
#
# File ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/sklearn/utils/validation.py:902, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900     # If input is 1D raise error
#     901     if array.ndim == 1:
# --> 902         raise ValueError(
#     903             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     904             "Reshape your data either using array.reshape(-1, 1) if "
#     905             "your data has a single feature or array.reshape(1, -1) "
#     906             "if it contains a single sample.".format(array)
#     907         )
#     909 if dtype_numeric and array.dtype.kind in "USV":
#     910     raise ValueError(
#     911         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     912         "Convert your data to numeric values explicitly instead."
#     913     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 0.30286053 13.815511   13.815511   ... 13.815511    4.6863
#  13.815308  ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
DC_saddle.idx
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 DC_saddle.idx
#
# AttributeError: 'DiffusionCurvature' object has no attribute 'idx'

# %%
X_sphere, ks_sphere = sphere(2000, d=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_sphere = graph_former(X_sphere)
DC_sphere = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_sphere.fit_transform(G_sphere, dim=2, t=25)

# %%
X_plane = plane(2000, dim=3)
graph_former = partial(get_adaptive_graph, alpha=1, k=5)
G_plane = graph_former(X_plane)
DC_plane = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Ollivier",
    graph_former=graph_former,
    points_per_cluster=None,  # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    distance_t = 25 # prevents the distances from changing along with the t value for easier comparison
)
ks = DC_plane.fit_transform(G_plane, dim=2, t=25)

# %%
show_curvature_curves(DC_saddle, DC_plane, DC_sphere, num_ts=50, title = " $W_1$ Spread of Diffusion in 3 Manifolds")

# %% [markdown]
# # Conclusion
