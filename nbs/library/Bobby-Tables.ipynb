# %%
#|default_exp bobby_tables
## Standard libraries
import os
import math
import numpy as np
import time
from fastcore.all import *
from nbdev.showdoc import *
# Configure environment
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false' # Tells Jax not to hog all of the memory to this process.

## Imports for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgba
import seaborn as sns
sns.set()

## Progress bar
from tqdm.auto import tqdm, trange

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Bobby "Father-of-all-Comparisons" Tables
# > A handy-dandy class for computing comparisons en masse

# %% [markdown]
# # Implementation

# %%
import pandas as pd
from fastcore.all import *
from tqdm.auto import *

class BobbyTables():
    def __init__(
        self,
        datasets, # a list containing the datasets; these will go in the columns
        methods, # a list containing functions which transform the dataset
        metrics, # a list containing metrics to apply to the transformed data. Should return scalar values.
        dataset_names = None,
    ):
        store_attr()
        if self.dataset_names is None:
            self.dataset_names = [f"Dataset {i+1}" for i in range(len(self.datasets))]
        self.transformed_data = 
        
        
        pd.DataFrame(index=self.dataset_names, 
                                             columns=[method.__name__ for method in self.methods])
    def compute_transforms(self):
        for X_name, X in tqdm(zip(self.dataset_names, self.datasets)):
            for f in tqdm(self.methods):
                # Create a dictionary with the transformed data
                X_dict = {'X': f(X)}
                # Assign the dictionary to the DataFrame cell
                self.transformed_data.loc[X_name, f.__name__] = X_dict

    def compute_metrics(self):
        for X_name in tqdm(self.dataset_names):
            for f in tqdm(self.methods):
                # Create a copy of the dictionary in the DataFrame cell
                X_dict = self.transformed_data.loc[X_name, f.__name__].copy()
                for met in tqdm(self.metrics):
                    # Compute the metric and add it to the dictionary
                    X_dict[met.__name__] = met(X_dict['X'])
                # Assign the updated dictionary back to the DataFrame cell
                self.transformed_data.loc[X_name, f.__name__] = X_dict

    def table(self, met, latex=False):
        try:
            # Create a new DataFrame based on the 'met' key from the dictionaries
            metric_data = self.transformed_data.applymap(lambda x: x.get(met, None))
        except AttributeError:
            print("The DataFrame does not contain dictionaries.")
            return

        # Print the data
        if latex:
            print(metric_data.to_latex())
        else:
            print(metric_data)

# %% [markdown]
# # Tests

# %%
# Test data
datasets = [np.array([1, 2, 3]), np.array([4, 5, 6]), np.array([7, 8, 9])]
methods = [np.square, np.sqrt]
metrics = [np.max, np.min]

# Create BobbyTables instance
bt = BobbyTables(datasets, methods, metrics)

# Compute transforms
bt.compute_transforms()

# Compute metrics
bt.compute_metrics()

# Print table
bt.table('max')
bt.table('min')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 metrics = [np.max, np.min]
#       6 # Create BobbyTables instance
# ----> 7 bt = BobbyTables(datasets, methods, metrics)
#       9 # Compute transforms
#      10 bt.compute_transforms()
#
# Cell In[2], line 16, in BobbyTables.__init__(self, datasets, methods, metrics, dataset_names)
#      14 if self.dataset_names is None:
#      15     self.dataset_names = [f"Dataset {i+1}" for i in range(len(self.datasets))]
# ---> 16 self.transformed_data = pl.DataFrame(
#      17     dict(zip([method.__name__ for method in self.methods], [None]*len(self.methods))),
#      18     index=self.dataset_names
#      19 )
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'index'

# %%
bt.transformed_data
# Out:
#           square sqrt
# Dataset 1    NaN  NaN
# Dataset 2    NaN  NaN
# Dataset 3    NaN  NaN

# %%
iterables = [["bar", "baz", "foo", "qux"], ["one", "two"]]
pd.MultiIndex.from_product(iterables)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            )

# %%
import xarray as xr

# %%
X_np = np.random.rand(4,9)

# %%
X_xr = xr.DataArray(X_np,dims=("x","y"))

# %%
X_xrS = [xr.DataArray(np.random.rand(4,9),dims=("x","y")) for i in range(10)]

# %%
X_xr.loc[2]
# Out:
# <xarray.DataArray (y: 9)>
# array([0.89399608, 0.08193993, 0.50300586, 0.54897443, 0.87916743,
#        0.02367836, 0.01886815, 0.53415272, 0.45676379])
# Dimensions without coordinates: y

# %%
X_xr.isel(y=1,x=2)
# Out:
# <xarray.DataArray ()>
# array(0.08193993)

# %%
X_xr.sel(y=1,x=2)
# Out:
# <xarray.DataArray ()>
# array(0.08193993)

# %%
X_xr.sel(y=[1,2])
# Out:
# <xarray.DataArray (x: 4, y: 2)>
# array([[0.79339217, 0.66540164],
#        [0.82873584, 0.54204883],
#        [0.08193993, 0.50300586],
#        [0.74514689, 0.51306626]])
# Dimensions without coordinates: x, y

# %%
X_xrS
# Out:
# [<xarray.DataArray (x: 4, y: 9)>
#  array([[0.63801396, 0.65111391, 0.38905505, 0.48182035, 0.57690872,
#          0.58420122, 0.39427126, 0.34458626, 0.64749813],
#         [0.61388341, 0.9153965 , 0.63027098, 0.98227745, 0.26944019,
#          0.75274306, 0.85683908, 0.13844137, 0.29495341],
#         [0.95036496, 0.57824576, 0.9320653 , 0.73240391, 0.14845341,
#          0.55105553, 0.2594477 , 0.30403977, 0.14443947],
#         [0.09564034, 0.82144494, 0.766945  , 0.30560011, 0.15359002,
#          0.38063087, 0.16932888, 0.48298054, 0.47097685]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.04914911, 0.26707203, 0.86984013, 0.46518003, 0.96210469,
#          0.77291233, 0.38735133, 0.40811404, 0.94863996],
#         [0.55196919, 0.23973144, 0.03705968, 0.35179575, 0.41900666,
#          0.12881975, 0.75446828, 0.54239917, 0.05909838],
#         [0.00814619, 0.93753326, 0.80325845, 0.2975334 , 0.43033077,
#          0.2253149 , 0.08891793, 0.89900395, 0.12252361],
#         [0.78463591, 0.30434009, 0.56810837, 0.93978122, 0.58157446,
#          0.83595901, 0.00506102, 0.42899898, 0.72790309]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.8522722 , 0.84197677, 0.36083007, 0.52042055, 0.83266912,
#          0.1687412 , 0.33080706, 0.48062999, 0.83563157],
#         [0.31341987, 0.5484956 , 0.02926525, 0.89759142, 0.33080714,
#          0.20982379, 0.63569099, 0.21101402, 0.67280109],
#         [0.61856962, 0.63979214, 0.50312565, 0.65031291, 0.25560308,
#          0.18943981, 0.93728797, 0.16895902, 0.954995  ],
#         [0.40217517, 0.74648641, 0.28715192, 0.59692023, 0.02250015,
#          0.56856367, 0.91364961, 0.99710104, 0.15425317]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.26273328, 0.22597548, 0.28636117, 0.44331452, 0.8526865 ,
#          0.80563002, 0.89264521, 0.03032108, 0.56234377],
#         [0.64850345, 0.49887858, 0.724704  , 0.21844409, 0.7108966 ,
#          0.50829449, 0.316662  , 0.25754082, 0.40075596],
#         [0.32911387, 0.63873025, 0.67318441, 0.39205089, 0.05531629,
#          0.81616256, 0.22753304, 0.93064049, 0.44671927],
#         [0.59148872, 0.56754584, 0.39865782, 0.27753166, 0.68303939,
#          0.89427568, 0.40349737, 0.21725518, 0.87573198]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.78930514, 0.1069053 , 0.06190611, 0.53518568, 0.82578756,
#          0.99323376, 0.57839935, 0.03733816, 0.54553884],
#         [0.84253037, 0.92142894, 0.36934138, 0.45689974, 0.96827652,
#          0.50015653, 0.45038542, 0.94931594, 0.51145167],
#         [0.63379356, 0.67636472, 0.8264147 , 0.4582407 , 0.79837062,
#          0.78241094, 0.52045808, 0.94093673, 0.72745315],
#         [0.34795467, 0.18482607, 0.27413788, 0.73259386, 0.20044399,
#          0.08724144, 0.69195985, 0.27651871, 0.86983118]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.08020625, 0.49386034, 0.53350328, 0.48912424, 0.86075436,
#          0.43417582, 0.54528744, 0.6684874 , 0.10594222],
#         [0.72762872, 0.59889366, 0.97719099, 0.94763144, 0.85209752,
#          0.282623  , 0.82163712, 0.08301018, 0.55849954],
#         [0.93144863, 0.82383224, 0.51257338, 0.2385801 , 0.80282793,
#          0.96892684, 0.41274352, 0.42372446, 0.14227286],
#         [0.00804825, 0.99760874, 0.52509239, 0.68856234, 0.82973023,
#          0.7591132 , 0.84875393, 0.20824513, 0.36332462]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[3.45804423e-01, 8.51780854e-01, 8.88084100e-01, 7.63561427e-01,
#          3.99390667e-01, 5.29060522e-01, 8.93414368e-01, 2.71841560e-01,
#          9.71192244e-01],
#         [4.15995114e-02, 8.33996707e-01, 2.33146285e-02, 4.68401950e-01,
#          8.73385144e-01, 7.55041407e-04, 5.46022344e-01, 8.61976828e-01,
#          4.69235339e-01],
#         [5.60215772e-01, 4.82543817e-01, 9.85066493e-01, 8.73325859e-01,
#          9.63260627e-01, 9.77273588e-01, 4.81325728e-01, 4.66229948e-01,
#          8.49542885e-01],
#         [8.74948205e-01, 2.46231890e-01, 8.65998264e-01, 9.45086553e-01,
#          9.77362546e-01, 2.54805150e-01, 6.71052211e-01, 2.09770179e-02,
#          1.59250482e-01]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.24350633, 0.15111387, 0.5763292 , 0.07605454, 0.60529535,
#          0.38203316, 0.91358872, 0.79391333, 0.94746242],
#         [0.91725186, 0.99625793, 0.64374782, 0.07071312, 0.05835324,
#          0.86989183, 0.72303081, 0.47630548, 0.13008547],
#         [0.22459223, 0.23950068, 0.71682077, 0.58228392, 0.95543858,
#          0.91800599, 0.58964468, 0.59428616, 0.91779061],
#         [0.94528644, 0.91358003, 0.73747313, 0.86563287, 0.81427814,
#          0.05341252, 0.52629655, 0.8633599 , 0.02951473]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.08609377, 0.69702398, 0.45239722, 0.00581269, 0.53118591,
#          0.10535604, 0.15695944, 0.19447082, 0.86511341],
#         [0.89993513, 0.50537815, 0.8947859 , 0.59890913, 0.53963898,
#          0.76865598, 0.32559943, 0.46547559, 0.09868316],
#         [0.50499887, 0.4985373 , 0.82070626, 0.84980601, 0.82774394,
#          0.33514966, 0.16876024, 0.71463233, 0.15539513],
#         [0.18213417, 0.90907523, 0.05679064, 0.64570589, 0.53678037,
#          0.31987743, 0.61291056, 0.41591758, 0.43031034]])
#  Dimensions without coordinates: x, y,
#  <xarray.DataArray (x: 4, y: 9)>
#  array([[0.27433528, 0.65128788, 0.09847893, 0.75899704, 0.95355476,
#          0.25675833, 0.5397193 , 0.01837647, 0.40466412],
#         [0.48139241, 0.8357288 , 0.492177  , 0.39814326, 0.7189774 ,
#          0.60629102, 0.81829429, 0.28853318, 0.63382939],
#         [0.81498038, 0.6135218 , 0.56125255, 0.24280277, 0.75057009,
#          0.80879196, 0.76816434, 0.02382475, 0.22092824],
#         [0.15722051, 0.18163309, 0.90327098, 0.92766123, 0.09550603,
#          0.49940085, 0.07180998, 0.47356556, 0.42777189]])
#  Dimensions without coordinates: x, y]

# %%
D = xr.Dataset(
        data_vars = {
            "method1": {
                "dataset1": (["n1","d1"],np.random.rand(10,2)),
                "dataset2": (["n2","d2"],np.random.rand(100,4)),
            }
            "method1": {
                "dataset1": (["n1","d1"],np.random.rand(10,2)),
                "dataset2": (["n2","d2"],np.random.rand(100,4)),
            }
            "method1": {
                "dataset1": (["n1","d1"],np.random.rand(10,2)),
                "dataset2": (["n2","d2"],np.random.rand(100,4)),
            }
        }
)
# Out:
#   Cell In[50], line 3
#     "method1": {
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import xarray as xr
import numpy as np

# Create inner datasets
ds1 = xr.Dataset(
    data_vars={"var1": (("x"), np.random.rand(5))},
    coords={"x": np.arange(5)},
)

ds2 = xr.Dataset(
    data_vars={"var2": (("y"), np.random.rand(3))}, 
    coords={"y": np.arange(3)}
)

# Create outer dataset 
outer_ds = xr.Dataset(
    data_vars={"ds1": ds1, "ds2": ds2},
)

print(outer_ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2720916/3030853278.py in ?()
#      12     coords={"y": np.arange(3)}
#      13 )
#      14
#      15 # Create outer dataset
# ---> 16 outer_ds = xr.Dataset(
#      17     data_vars={"ds1": ds1, "ds2": ds2},
#      18 )
#      19
#
# ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/xarray/core/dataset.py in ?(self, data_vars, coords, attrs)
#     690
#     691         if isinstance(coords, Dataset):
#     692             coords = coords._variables
#     693
# --> 694         variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#     695             data_vars, coords
#     696         )
#     697
#
# ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/xarray/core/dataset.py in ?(data_vars, coords)
#     419         coords = create_coords_with_default_indexes(coords, data_vars)
#     420
#     421     # exclude coords from alignment (all variables in a Coordinates object should
#     422     # already be aligned together) and use coordinates' indexes to align data_vars
# --> 423     return merge_core(
#     424         [data_vars, coords],
#     425         compat="broadcast_equals",
#     426         join="outer",
#
# ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/xarray/core/merge.py in ?(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value, skip_align_args)
#     714
#     715     for pos, obj in skip_align_objs:
#     716         aligned.insert(pos, obj)
#     717
# --> 718     collected = collect_variables_and_indexes(aligned, indexes=indexes)
#     719     prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#     720     variables, out_indexes = merge_collected(
#     721         collected, prioritized, compat=compat, combine_attrs=combine_attrs
#
# ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/xarray/core/merge.py in ?(list_of_mappings, indexes)
#     354                 coords_.pop(name, None)
#     355                 indexes_.pop(name, None)
#     356                 append_all(coords_, indexes_)
#     357
# --> 358             variable = as_variable(variable, name=name)
#     359             if name in indexes:
#     360                 append(name, variable, indexes[name])
#     361             elif variable.dims == (name,):
#
# ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/xarray/core/variable.py in ?(obj, name)
#     139         obj = Variable(obj.name, obj)
#     140     elif isinstance(obj, (set, dict)):
#     141         raise TypeError(f"variable {name!r} has invalid type {type(obj)!r}")
#     142     elif name is not None:
# --> 143         data: T_DuckArray = as_compatible_data(obj)
#     144         if data.ndim != 1:
#     145             raise MissingDimensionsError(
#     146                 f"cannot set variable {name!r} with {data.ndim!r}-dimensional data "
#
# ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/xarray/core/variable.py in ?(data, fastpath)
#     281     ):
#     282         return cast("T_DuckArray", data)
#     283
#     284     # validate whether the data is valid data types.
# --> 285     data = np.asarray(data)
#     286
#     287     if isinstance(data, np.ndarray) and data.dtype.kind in "OMm":
#     288         data = _possibly_convert_objects(data)
#
# ~/mambaforge/envs/zetteldev-diffcurv/lib/python3.11/site-packages/xarray/core/dataset.py in ?(self, dtype)
#    1498         def __array__(self, dtype=None):
# -> 1499             raise TypeError(
#    1500                 "cannot directly convert an xarray.Dataset into a "
#    1501                 "numpy array. Instead, create an xarray.DataArray "
#    1502                 "first, either with indexing on the Dataset or by "
#
# TypeError: cannot directly convert an xarray.Dataset into a numpy array. Instead, create an xarray.DataArray first, either with indexing on the Dataset or by invoking the `to_dataarray()` method.

# %%
D

# %%
# sync changes to the library
from IPython.display import display, Javascript
import time
display(Javascript('IPython.notebook.save_checkpoint();'))
time.sleep(2)
# !pixi run nbsync
