# %%
#|hide
## Standard libraries
import os
import math
import numpy as np
import time
from fastcore.all import *
from nbdev.showdoc import *

# Configure environment
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false' # Tells Jax not to hog all of the memory to this process.

## Imports for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgba
import seaborn as sns
sns.set()

## Progress bar
from tqdm.auto import tqdm, trange

## project specifics
import diffusion_curvature
import pygsp
import jax
import jax.numpy as jnp
jax.devices()

from diffusion_curvature.graphs import *
from diffusion_curvature.datasets import *
from diffusion_curvature.core import *
from diffusion_curvature.utils import *
from diffusion_curvature.comparison_space import *

# %load_ext autoreload
# %autoreload 2
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 34
#      32 from diffusion_curvature.graphs import *
#      33 from diffusion_curvature.datasets import *
# ---> 34 from diffusion_curvature.core import *
#      35 from diffusion_curvature.utils import *
#      36 from diffusion_curvature.comparison_space import *
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/core.py:32
#      30 # Comparison space construction
#      31 from .comparison_space import EuclideanComparisonSpace, fit_comparison_space_model, euclidean_comparison_graph, construct_ndgrid_from_shape, diffusion_coordinates, load_average_entropies
# ---> 32 from .normalizing_flows import neural_flattener
#      33 from .flattening.mioflow_quicktrain import MIOFlowStandard
#      34 from .flattening.radial_ae import radially_flatten_with_ae
#
# File ~/Pumberton/Workshop/21-SUMRY-Curvature/diffusion-curvature/src/diffusion_curvature/normalizing_flows.py:8
#       4 __all__ = ['ManifoldNeighborhoodDataset', 'dataloader_from_manifold_neighborhoods', 'FlowNet', 'NegativeLogLikelihood',
#       5            'NegativeLogLikelihoodQuaUniform', 'GreatFlattener', 'neural_flattener']
#       7 # %% ../../nbs/experiments/3e3-flattening-with-continuous-normalizing-flows.ipynb 4
# ----> 8 import torch, torch.nn as nn, torch.utils.data as data, torch.nn.functional as F, torch.optim as optim
#       9 import ot
#      10 from torchdyn.core import NeuralODE
#
# ModuleNotFoundError: No module named 'torch.nn'

# %% [markdown]
# # 3g Making Diffusion Curvature Density Invariant

# %% [markdown]
# - Take several densities of sampling of the saddle by linearly increasing n_points; plot diffusion curvature across the increasing dimension
#     - Do both on ‘top’ and ‘bottom’; for space and its neural flattening.
#     - Try subtracting and dividing the verticals, using “Subtraction” and “Ollivier” comparison_type.
#         - Does
#     - Try normalizing by density

# %% [markdown]
# **Hypothesis**: Diffusion Laziness will decrease as density increases. Comparing with a flattened space will negate this effect.

# %% [markdown]
# # Machinery

# %%
# Out:
# array([ 500.        ,  564.1025641 ,  628.20512821,  692.30769231,
#         756.41025641,  820.51282051,  884.61538462,  948.71794872,
#        1012.82051282, 1076.92307692, 1141.02564103, 1205.12820513,
#        1269.23076923, 1333.33333333, 1397.43589744, 1461.53846154,
#        1525.64102564, 1589.74358974, 1653.84615385, 1717.94871795,
#        1782.05128205, 1846.15384615, 1910.25641026, 1974.35897436,
#        2038.46153846, 2102.56410256, 2166.66666667, 2230.76923077,
#        2294.87179487, 2358.97435897, 2423.07692308, 2487.17948718,
#        2551.28205128, 2615.38461538, 2679.48717949, 2743.58974359,
#        2807.69230769, 2871.79487179, 2935.8974359 , 3000.        ])

# %%
from diffusion_curvature.datasets import rejection_sample_from_saddle
def compare_diffusion_curvature_across_densities(DC, dim=2, t = 25, graphformer = get_adaptive_graph):
    ns = np.linspace(500, 3000, 40).astype(int)
    ks = []
    for n in tqdm(ns):
        s = rejection_sample_from_saddle(n, dim)[0]
        g = graphformer(s)
        k = DC.curvature(
            g, t = t, dim=dim
        )
        ks.append(k[0])
    plt.plot(ns, ks)
    plt.title(f"Diffusion Curvature with {t=} in {dim=} over increasing densities")
    plt.xlabel("Num Points")
    return ks

# %% [markdown]
# # Results

# %%
from functools import partial
graphformer = graphtools_graph_from_data

# %%
X, ks = rejection_sample_from_saddle(2000, intrinsic_dim=2)
G = graphformer(X)

# %%
DC = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Fixed",
    comparison_method="Subtraction",
    points_per_cluster=None, # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    graph_former=graphformer
)

# %%
k = DC.curvature(G, dim=2, t=25)

# %%
plot_3d(X,k, colorbar=True)

# %%
ks_over_time = compare_diffusion_curvature_across_densities(DC, dim = 2, graphformer=graphformer)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
ks_over_time = compare_diffusion_curvature_across_densities(DC, dim = 3, graphformer=graphformer)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %% [markdown]
# ## With Radial Flattening

# %%
DC = DiffusionCurvature(
    laziness_method="Wasserstein",
    flattening_method="Radial Flattening",
    comparison_method="Subtraction",
    points_per_cluster=None, # construct separate comparison spaces around each point
    comparison_space_size_factor=1,
    verbose=False,
    graph_former=graphformer
)

# %%
DC.curvature(G, t=25, dim=2)
# Out:
# Array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)

# %%
ks_over_time = compare_diffusion_curvature_across_densities(DC, dim = 2)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# 2024-03-22 15:20:59,188:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:20:59,404:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:20:59,699:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:00,081:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:00,573:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:01,176:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:01,906:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:02,799:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:03,873:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:05,160:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:06,715:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:08,513:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:10,629:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:13,091:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:15,918:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:19,104:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:22,647:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:26,653:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:31,141:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:36,183:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:41,600:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:47,670:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:21:54,506:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:22:02,682:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:22:12,491:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:22:22,554:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:22:33,986:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:22:46,528:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:23:00,135:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:23:15,039:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:23:31,295:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:23:49,009:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:24:07,971:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:24:28,241:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:24:50,055:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:25:13,433:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:25:38,451:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:26:05,303:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:26:33,950:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!
# 2024-03-22 15:27:04,497:[WARNING](pygsp.graphs.graph.check_weights): The main diagonal of the weight matrix is not 0!

# %% [markdown]
# # Conclusion
