# %% [raw]
# ---
# output-file: 0a-atoms.html
# title: Atoms
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# The building blocks of our method. The fundamentals. The shoulders of giants.
# Implemented from scratch whenever possible.
